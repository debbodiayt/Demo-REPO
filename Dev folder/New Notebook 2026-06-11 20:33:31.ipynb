# %%
# %py
print("Hello");

# %% [markdown]
# # Title 1
# ## Title 1
# ### Title 1
#
# **Title**
# *Title*
#
# [](https://spark.apache.org/docs/latest/sql-ref-datetime-pattern.html)
#
#
# Images : ![](https://www.sony.co.jp/en/Products/di_photo-gallery/images/extralarge/1887.JPG)
#
# 1. List 1
# 2. List 2
#
# > Hello

# %%
# %run ./Includes/setup

# %%
print(full_name)

# %%
# %fs ls '/databricks-datasets'

# %%
dbutils.help()

# %%
dbutils.fs.help()

# %%
file=dbutils.fs.ls('/databricks-datasets')
print(file)

# %% [markdown]
# since the udutils output hard to read , use below display function.

# %%
display(file)

# %% [markdown]
# Below i have added breakpoints in the code which helps to debug the code execution efficiently

# %%
import time
x=8
print(x)
y=9
print(y)
